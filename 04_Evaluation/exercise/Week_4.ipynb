# %%
# print("Hello World!")

# %% [markdown]
# # 4. Evaluation Metrics for Classification

# %% [markdown]
# ## 4.1 Evaluation metrics: session overview

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# !wget https://raw.githubusercontent.com/alexeygrigorev/mlbookcamp-code/master/chapter-03-churn-prediction/WA_Fn-UseC_-Telco-Customer-Churn.csv
# Out:
# --2026-07-13 09:22:03--  https://raw.githubusercontent.com/alexeygrigorev/mlbookcamp-code/master/chapter-03-churn-prediction/WA_Fn-UseC_-Telco-Customer-Churn.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 977501 (955K) [text/plain]
# Saving to: ‘WA_Fn-UseC_-Telco-Customer-Churn.csv’
#
# WA_Fn-UseC_-Telco-C 100%[===================>] 954.59K  5.59MB/s    in 0.2s
#
# 2026-07-13 09:22:04 (5.59 MB/s) - ‘WA_Fn-UseC_-Telco-Customer-Churn.csv’ saved [977501/977501]

# %%
df = pd.read_csv('/content/WA_Fn-UseC_-Telco-Customer-Churn.csv')

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')
categorical_columns = list(df.dtypes[df.dtypes == 'object'].index)

for c in categorical_columns:
    df[c] = df[c].str.lower().str.replace(' ', '_')

df.totalcharges = pd.to_numeric(df.totalcharges, error='coerce')
df.totalcharges = df.totalcharges.fillna(0)

df.churn = (df.churn == 'yes').astype(int)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2006/1012653217.py in <cell line: 0>()
#       5     df[c] = df[c].str.lower().str.replace(' ', '_')
#       6
# ----> 7 df.totalcharges = pd.to_numeric(df.totalcharges, error='coerce')
#       8 df.totalcharges = df.totalcharges.fillna(0)
#       9
#
# TypeError: to_numeric() got an unexpected keyword argument 'error'
